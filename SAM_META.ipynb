# %%
# !pip install -r requirements.txt
# !wget https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Out:
# Collecting git+https://github.com/facebookresearch/segment-anything.git (from -r requirements.txt (line 5))
#   Cloning https://github.com/facebookresearch/segment-anything.git to /tmp/pip-req-build-_j85filc
#   Running command git clone -q https://github.com/facebookresearch/segment-anything.git /tmp/pip-req-build-_j85filc
# Requirement already satisfied (use --upgrade to upgrade): segment-anything==1.0 from git+https://github.com/facebookresearch/segment-anything.git in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 5))
# Requirement already satisfied: matplotlib in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 1)) (3.7.1)
# Requirement already satisfied: torch in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: torchaudio in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 3)) (2.0.1)
# Requirement already satisfied: torchvision in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 4)) (0.15.1)
# Requirement already satisfied: opencv-python in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 6)) (4.7.0.72)
# Requirement already satisfied: pycocotools in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 7)) (2.0.6)
# Requirement already satisfied: onnxruntime in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 8)) (1.14.1)
# Requirement already satisfied: onnx in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 9)) (1.13.1)
# Requirement already satisfied: numpy in /config/.local/lib/python3.8/site-packages (from -r requirements.txt (line 10)) (1.24.2)
# Requirement already satisfied: pillow>=6.2.0 in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (9.5.0)
# Requirement already satisfied: packaging>=20.0 in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (23.1)
# Requirement already satisfied: fonttools>=4.22.0 in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (4.39.3)
# Requirement already satisfied: cycler>=0.10 in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (0.11.0)
# Requirement already satisfied: kiwisolver>=1.0.1 in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (1.4.4)
# Requirement already satisfied: python-dateutil>=2.7 in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (2.8.2)
# Requirement already satisfied: pyparsing>=2.3.1 in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (3.0.9)
# Requirement already satisfied: contourpy>=1.0.1 in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (1.0.7)
# Requirement already satisfied: importlib-resources>=3.2.0; python_version < "3.10" in /config/.local/lib/python3.8/site-packages (from matplotlib->-r requirements.txt (line 1)) (5.12.0)
# Requirement already satisfied: typing-extensions in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (4.5.0)
# Requirement already satisfied: nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (11.7.91)
# Requirement already satisfied: nvidia-cusparse-cu11==11.7.4.91; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (11.7.4.91)
# Requirement already satisfied: nvidia-nccl-cu11==2.14.3; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (2.14.3)
# Requirement already satisfied: sympy in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (1.11.1)
# Requirement already satisfied: nvidia-cudnn-cu11==8.5.0.96; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (8.5.0.96)
# Requirement already satisfied: nvidia-cuda-runtime-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (11.7.99)
# Requirement already satisfied: triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (2.0.0)
# Requirement already satisfied: nvidia-cufft-cu11==10.9.0.58; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (10.9.0.58)
# Requirement already satisfied: jinja2 in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (3.1.2)
# Requirement already satisfied: nvidia-cuda-nvrtc-cu11==11.7.99; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (11.7.99)
# Requirement already satisfied: nvidia-curand-cu11==10.2.10.91; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (10.2.10.91)
# Requirement already satisfied: nvidia-cusolver-cu11==11.4.0.1; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (11.4.0.1)
# Requirement already satisfied: nvidia-cublas-cu11==11.10.3.66; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (11.10.3.66)
# Requirement already satisfied: nvidia-cuda-cupti-cu11==11.7.101; platform_system == "Linux" and platform_machine == "x86_64" in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (11.7.101)
# Requirement already satisfied: networkx in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (3.1)
# Requirement already satisfied: filelock in /config/.local/lib/python3.8/site-packages (from torch->-r requirements.txt (line 2)) (3.11.0)
# Requirement already satisfied: requests in /config/.local/lib/python3.8/site-packages (from torchvision->-r requirements.txt (line 4)) (2.28.2)
# Requirement already satisfied: coloredlogs in /config/.local/lib/python3.8/site-packages (from onnxruntime->-r requirements.txt (line 8)) (15.0.1)
# Requirement already satisfied: protobuf in /config/.local/lib/python3.8/site-packages (from onnxruntime->-r requirements.txt (line 8)) (4.22.3)
# Requirement already satisfied: flatbuffers in /config/.local/lib/python3.8/site-packages (from onnxruntime->-r requirements.txt (line 8)) (23.3.3)
# Requirement already satisfied: six>=1.5 in /config/.local/lib/python3.8/site-packages (from python-dateutil>=2.7->matplotlib->-r requirements.txt (line 1)) (1.16.0)
# Requirement already satisfied: zipp>=3.1.0; python_version < "3.10" in /config/.local/lib/python3.8/site-packages (from importlib-resources>=3.2.0; python_version < "3.10"->matplotlib->-r requirements.txt (line 1)) (3.15.0)
# Requirement already satisfied: setuptools in /usr/lib/python3/dist-packages (from nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64"->torch->-r requirements.txt (line 2)) (45.2.0)
# Requirement already satisfied: wheel in /usr/lib/python3/dist-packages (from nvidia-nvtx-cu11==11.7.91; platform_system == "Linux" and platform_machine == "x86_64"->torch->-r requirements.txt (line 2)) (0.34.2)
# Requirement already satisfied: mpmath>=0.19 in /config/.local/lib/python3.8/site-packages (from sympy->torch->-r requirements.txt (line 2)) (1.3.0)
# Requirement already satisfied: lit in /config/.local/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch->-r requirements.txt (line 2)) (16.0.1)
# Requirement already satisfied: cmake in /config/.local/lib/python3.8/site-packages (from triton==2.0.0; platform_system == "Linux" and platform_machine == "x86_64"->torch->-r requirements.txt (line 2)) (3.26.3)
# Requirement already satisfied: MarkupSafe>=2.0 in /config/.local/lib/python3.8/site-packages (from jinja2->torch->-r requirements.txt (line 2)) (2.1.2)
# Requirement already satisfied: charset-normalizer<4,>=2 in /config/.local/lib/python3.8/site-packages (from requests->torchvision->-r requirements.txt (line 4)) (3.1.0)
# Requirement already satisfied: urllib3<1.27,>=1.21.1 in /config/.local/lib/python3.8/site-packages (from requests->torchvision->-r requirements.txt (line 4)) (1.26.15)
# Requirement already satisfied: certifi>=2017.4.17 in /config/.local/lib/python3.8/site-packages (from requests->torchvision->-r requirements.txt (line 4)) (2022.12.7)
# Requirement already satisfied: idna<4,>=2.5 in /config/.local/lib/python3.8/site-packages (from requests->torchvision->-r requirements.txt (line 4)) (3.4)
# Requirement already satisfied: humanfriendly>=9.1 in /config/.local/lib/python3.8/site-packages (from coloredlogs->onnxruntime->-r requirements.txt (line 8)) (10.0)
# Building wheels for collected packages: segment-anything
#   Building wheel for segment-anything (setup.py) ... done
#   Created wheel for segment-anything: filename=segment_anything-1.0-py3-none-any.whl size=36610 sha256=7634b2c9ea8545ee6f7edc76fb5f6f250640cc3c838277bda2cfd2fc74c5d6be
#   Stored in directory: /tmp/pip-ephem-wheel-cache-vxsl1fb6/wheels/b0/7e/40/20f0b1e23280cc4a66dc8009c29f42cb4afc1b205bc5814786
# Successfully built segment-anything
# --2023-04-16 21:40:47--  https://dl.fbaipublicfiles.com/segment_anything/sam_vit_h_4b8939.pth
# Resolving dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)... 108.158.46.124, 108.158.46.39, 108.158.46.73, ...
# Connecting to dl.fbaipublicfiles.com (dl.fbaipublicfiles.com)|108.158.46.124|:443... connected.
# HTTP request sent, awaiting response... 200 OK
# Length: 2564550879 (2.4G) [binary/octet-stream]
# Saving to: ‘sam_vit_h_4b8939.pth’
#
# sam_vit_h_4b8939.pt 100%[===================>]   2.39G  3.69MB/s    in 8m 22s
#
# 2023-04-16 21:49:10 (4.87 MB/s) - ‘sam_vit_h_4b8939.pth’ saved [2564550879/2564550879]

# %%
import numpy as np
import torch
import matplotlib.pyplot as plt
import cv2

# %%
def show_anns(anns):
    if len(anns) == 0:
        return
    sorted_anns = sorted(anns, key=(lambda x: x['area']), reverse=True)
    ax = plt.gca()
    ax.set_autoscale_on(False)
    polygons = []
    color = []
    for ann in sorted_anns:
        m = ann['segmentation']
        img = np.ones((m.shape[0], m.shape[1], 3))
        color_mask = np.random.random((1, 3)).tolist()[0]
        for i in range(3):
            img[:,:,i] = color_mask[i]
        ax.imshow(np.dstack((img, m*0.35)))

# %%
image = cv2.imread('img_1.jpg')
image = cv2.cvtColor(image, cv2.COLOR_BGR2RGB)

# %%
plt.figure(figsize=(20,20))
plt.imshow(image)
plt.axis('off')
plt.show()

# %%
import sys
sys.path.append("..")
from segment_anything import sam_model_registry, SamAutomaticMaskGenerator, SamPredictor

sam_checkpoint = "sam_vit_h_4b8939.pth"
model_type = "vit_h"

device = "cuda"

sam = sam_model_registry[model_type](checkpoint=sam_checkpoint)
sam.to(device=device)

mask_generator = SamAutomaticMaskGenerator(sam)

# %%
masks = mask_generator.generate(image)

# %%
plt.figure(figsize=(20,20))
plt.imshow(image)
show_anns(masks)
plt.axis('off')
plt.show()
